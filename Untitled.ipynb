# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import Imputer
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
import xgboost as xgb


df=pd.read_csv('train.csv')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df['Marital_Status'].value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
df['Product_Category_1'].value_counts()
# Out:
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: Product_Category_1, dtype: int64

# %%
df['Product_Category_2'].value_counts()
# Out:
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: Product_Category_2, dtype: int64

# %%
df['Product_Category_3'].value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %%
train=df.drop(['User_ID','Product_ID'], axis=1)

# %%
#now let's impute the missing values

train.fillna(train.mean())
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# 5           M  26-35          15             A                          3
# 6           M  46-50           7             B                          2
# 7           M  46-50           7             B                          2
# 8           M  46-50           7             B                          2
# 9           M  26-35          20             A                          1
# 10          M  26-35          20             A                          1
# 11          M  26-35          20             A                          1
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
train['Purchase'].plot.hist(bins=50)

# %%
#from the  above distribution we can see that a high number of people have a purchase amount of 5000-10000, and very less people purchased for 220000+
#now to begin with eda

#target variable=purchase amount
#independent variable= rest of all the variables

#for starters let's start off by checking the relation between age groups and purchase amount

train['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
#from the above observation a lot more of the shoppers age from 26-35,

sns.catplot(x="Age", y="Purchase", kind="box", data=train)

# %%
#from the above plot different age groups seem to have spent different amounts of money, with the age group 51-55, being the highest
#so age is definitely a decent predictor of purchase ,they seem to have some sort of relationship and also there are a lot of outliers,which we will filter out later.

# %%
#now let's plot the relation between gender and purchase

train['Gender'].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
#whoa! the males seem more interested in the black friday shopping more than the females, strange isn't it? 
#now let's check how much each gender group have spent for black-friday


sns.catplot(x="Gender", y="Purchase", hue="Gender",kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#again no surprises that males have spent more considering their high strength,but the females having been for shopping so low in numbers have managed to get relatively close.
#so gender is also a good predictor of purchase

#now let's perform a groupby operation to get more insights on the age,gender and purchase pattern

group= train['Purchase'].groupby([train['Age'],train['Gender']]).mean()
group
# Out:
# Age    Gender
# 0-17   F         8338.771985
#        M         9235.173670
# 18-25  F         8343.180201
#        M         9440.942971
# 26-35  F         8728.251754
#        M         9410.337578
# 36-45  F         8959.844056
#        M         9453.193643
# 46-50  F         8842.098947
#        M         9357.471509
# 51-55  F         9042.449666
#        M         9705.094802
# 55+    F         9007.036199
#        M         9438.195603
# Name: Purchase, dtype: float64

# %%
#so the highest amount was spent by the males of the 51-55 age group, and the least was spent by the females of the age group 0-17,
sns.catplot(x="Occupation",y="Purchase", kind="box",data=train)

# %%
#as can be seen from the above graph,people from the occupations 12,15, and 17 tend to spend a lot more than the people from the other occupations
#now let's perform another gropu by operation ,this time with the occupation variable.
train['Purchase'].groupby([train['Age'],train['Gender'],train['Occupation']]).mean()
# Out:
# Age    Gender  Occupation
# 0-17   F       0              9115.919679
#                1              9982.919075
#                2              7807.615385
#                7              8730.046512
#                10             8204.280531
#                19             5668.713043
#        M       0              9407.115357
#                1              7755.551402
#                2              9461.452830
#                4              9431.964602
#                7             11306.968750
#                8             10485.862069
#                10             9234.140259
#                11             7574.611111
#                12             8095.827004
#                13             8970.200000
#                14            11624.344086
#                17            10401.028571
#                19             9028.421965
# 18-25  F       0              8524.411660
#                1              7741.795858
#                2              7386.670817
# ...

# %%
#so the occupation variable is also responsible for the purchase amount.let's visualize this with another bar plot

sns.catplot(x="Occupation", y="Purchase", kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#as you can see , the purchase rates vary for every different occupation. so occupation is also a useful predictor.
train.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
#now let's analyze the city category.
#as usual let's plot a box plot

sns.catplot(x="City_Category",y="Purchase", kind="box", data=train)

# %%
#not much difference between the cities A and B, but the people from city C tend to spend a lot more than the people from the other cities.
#therefore the city category is also useful in predicting the purchase price.let's plot some more useful graphs.
sns.catplot(x="City_Category", y="Purchase", hue="Gender",kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#so males from every city spend more than the females,now let's plot another graph to find out which age gropup spends more for every city
sns.catplot(x="City_Category",y="Purchase", hue="Age", kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#51-55 age group spends more in city A, age groups 26-35,51-55,and 36-45 spend more in city B, and 55+ spend more in city c,
train['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
#let's perform another group by 
train['Purchase'].groupby([train['Stay_In_Current_City_Years']]).mean()
# Out:
# Stay_In_Current_City_Years
# 0     9180.075123
# 1     9250.145923
# 2     9320.429810
# 3     9286.904119
# 4+    9275.598872
# Name: Purchase, dtype: float64

# %%
#there doesn't seem to be much of an effect on the purchase, regardless of how many years the people stayed in the cities,the 
#averages don't differ much, so we can discard this variable during the training stage.
train['Marital_Status'].value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
sns.catplot(x="Marital_Status", y="Purchase", kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#from the above graph both the married and the unmarried have the same purchase rate,now let's test this hypothesis with the gender as hue.
sns.catplot(x="Marital_Status", y="Purchase",hue="Gender", kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#oh! the men buy more regardless of their marital status,let's continue with the analysis of other variables.
train['Product_Category_1'].value_counts()
# Out:
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: Product_Category_1, dtype: int64

# %%
#product category 5 was purchased the most.
#now let's see which age group purchased the 5th category,
sns.catplot(x="Age",y="Product_Category_1",kind="bar",data=train)
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#category 5 was purchased by the people of age 0-17, so this definitely influences the purchase prediction, and so will the other 
#product categories
#now since all the features except purchase are categorical, so we don't have to perform any feature transformation.
sns.distplot(df['Purchase'])
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
np.log(train['Purchase'])
# Out:
# 0         9.032409
# 1         9.629051
# 2         7.259820
# 3         6.963190
# 4         8.983314
# 5         9.630825
# 6         9.863447
# 7         9.671177
# 8         9.660524
# 9         8.970940
# 10        8.566745
# 11        8.283241
# 12        8.711608
# 13        9.659184
# 14        8.590072
# 15        7.639642
# 16        9.476926
# 17        9.088286
# 18        9.374837
# 19        9.883999
# 20        9.057655
# 21        9.197458
# 22        9.184304
# 23        8.696510
# 24        9.386560
# 25        9.720886
# 26        8.680502
# 27        8.849801
# 28        8.592486
# 29        9.702105
#             ...
# 550038    6.390241
# 550039    6.388561
# 550040    3.258097
# 550041    6.190315
# 550042    5.493061
# 550043    3.871201
# 550044    4.127134
# 550045    5.529429
# 550046    5.463832
# 550047    5.497168
# 550048    6.381816
# 550049    6.159095
# 550050    5.908083
# 550051    6.192362
# 550052    5.476464
# 550053    5.916202
# ...

# %%
sns.distplot(train['Purchase'])
# Out:
# C:\Users\Abhinay Ratakonda\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#now let's one-hot encode the categorical values by getting the dummy variables
train.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
train=pd.get_dummies(train)
train.head()
# Out:
#    Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0          10               0                   3                 NaN
# 1          10               0                   1                 6.0
# 2          10               0                  12                 NaN
# 3          10               0                  12                14.0
# 4          16               0                   8                 NaN
#
#    Product_Category_3  Purchase  Gender_F  Gender_M  Age_0-17  Age_18-25  \
# 0                 NaN      8370         1         0         1          0
# 1                14.0     15200         1         0         1          0
# 2                 NaN      1422         1         0         1          0
# 3                 NaN      1057         1         0         1          0
# 4                 NaN      7969         0         1         0          0
#
#                ...                Age_51-55  Age_55+  City_Category_A  \
# ...

# %%
#first we started off with 12 columns, now with one hot encoding ,we have 27 features
train.head()
# Out:
#    Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0          10               0                   3                 NaN
# 1          10               0                   1                 6.0
# 2          10               0                  12                 NaN
# 3          10               0                  12                14.0
# 4          16               0                   8                 NaN
#
#    Product_Category_3  Purchase  Gender_F  Gender_M  Age_0-17  Age_18-25  \
# 0                 NaN      8370         1         0         1          0
# 1                14.0     15200         1         0         1          0
# 2                 NaN      1422         1         0         1          0
# 3                 NaN      1057         1         0         1          0
# 4                 NaN      7969         0         1         0          0
#
#                ...                Age_51-55  Age_55+  City_Category_A  \
# ...

# %%
X=train
y=X['Purchase']
X=X.drop(['Purchase'], axis=1)
imp = Imputer(missing_values="NaN", strategy='most_frequent', axis=0)
X=imp.fit_transform(X)
data_dmatrix = xgb.DMatrix(data=X,label=y)
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# [01:22:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [01:22:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [01:22:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [01:22:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [01:22:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=4
# [01:22:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# ...
